# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
from  matplotlib import pyplot as plt
import seaborn as sns
import missingno as msno
#import plotly.express as px

# %%
df_tracks = pd.read_csv(r"C:\Users\mareg\OneDrive\Escritorio\SPOTIFY CSV\archive (4)\tracks.csv", encoding = "UTF-8",parse_dates=['release_date'])
df_tracks.head()
# Out:
#                        id                                 name  popularity  \
# 0  35iwgR4jXetI318WEWsa1Q                                Carve           6
# 1  021ht4sdgPcrDgSk7JTbKY  Capítulo 2.16 - Banquero Anarquista           0
# 2  07A5yehtSnoedViJAZkNnc   Vivo para Quererte - Remasterizado           0
# 3  08FmqUhxtyLTn6pAh6bk45        El Prisionero - Remasterizado           0
# 4  08y9GfoqCWfOGsKdwojr5e                  Lady of the Evening           0
#
#    duration_ms  explicit              artists                  id_artists  \
# 0       126903         0              ['Uli']  ['45tIt06XoI0Iio4LBEVpls']
# 1        98200         0  ['Fernando Pessoa']  ['14jtPCOoNZwquk5wd9DxrY']
# 2       181640         0  ['Ignacio Corsini']  ['5LiOoJbxVSAMkBS2fUm3X2']
# 3       176907         0  ['Ignacio Corsini']  ['5LiOoJbxVSAMkBS2fUm3X2']
# 4       163080         0      ['Dick Haymes']  ['3BiJGZsyX9sJchTqcSA7Su']
#
# ...

# %%
df_tracks.shape
# Out:
# (586672, 20)

# %%
df_tracks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 586672 entries, 0 to 586671
# Data columns (total 20 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   id                586672 non-null  object
#  1   name              586601 non-null  object
#  2   popularity        586672 non-null  int64
#  3   duration_ms       586672 non-null  int64
#  4   explicit          586672 non-null  int64
#  5   artists           586672 non-null  object
#  6   id_artists        586672 non-null  object
#  7   release_date      586672 non-null  datetime64[ns]
#  8   danceability      586672 non-null  float64
#  9   energy            586672 non-null  float64
#  10  key               586672 non-null  int64
#  11  loudness          586672 non-null  float64
#  12  mode              586672 non-null  int64
#  13  speechiness       586672 non-null  float64
#  14  acousticness      586672 non-null  float64
# ...

# %%
df_charts = pd.read_csv(r"C:\Users\mareg\Downloads\archive (6)\charts.csv", encoding = "UTF-8")
df_charts.head()
# Out:
#          date country  position  streams                track_id  \
# 0  2021/04/15      de        82   625718  20IvMlpi4U5RuDnAlXSRiV
# 1  2019/01/31      jp       171    50896  0V1K6MU0utODk4yNqZKsFv
# 2  2018/11/15      tr        59   185439  4qzZm5EIdFurBpDieEmVc9
# 3  2018/11/22      tr       133   111159  4qzZm5EIdFurBpDieEmVc9
# 4  2018/11/29      tr       166    96204  4qzZm5EIdFurBpDieEmVc9
#
#           artists                                      artist_genres  \
# 0  ['Haftbefehl']                                 ['german hip hop']
# 1     ['Suchmos']  ['japanese r&b', 'j-rock', 'japanese soul', 'j...
# 2    ['Nilipek.']      ['turkish singer-songwriter', 'turkish rock']
# 3    ['Nilipek.']      ['turkish singer-songwriter', 'turkish rock']
# 4    ['Nilipek.']      ['turkish singer-songwriter', 'turkish rock']
#
#    duration  explicit                name
# 0    198746     False          Crackküche
# 1    408320     False               WATER
# ...

# %%
df_charts.columns
# Out:
# Index(['date', 'country', 'position', 'streams', 'id', 'artists',
#        'artist_genres', 'duration', 'explicit', 'name'],
#       dtype='object')

# %%
df_charts.shape
# Out:
# (5428021, 10)

# %%
df_charts.isnull().sum()
# Out:
# date               0
# country            0
# position           0
# streams            0
# track_id           0
# artists            0
# artist_genres      0
# duration           0
# explicit           0
# name             885
# dtype: int64

# %%
df_charts = df_charts.rename(columns={'track_id': 'id'})
df_charts.head()
# Out:
#          date country  position  streams                      id  \
# 0  2021/04/15      de        82   625718  20IvMlpi4U5RuDnAlXSRiV
# 1  2019/01/31      jp       171    50896  0V1K6MU0utODk4yNqZKsFv
# 2  2018/11/15      tr        59   185439  4qzZm5EIdFurBpDieEmVc9
# 3  2018/11/22      tr       133   111159  4qzZm5EIdFurBpDieEmVc9
# 4  2018/11/29      tr       166    96204  4qzZm5EIdFurBpDieEmVc9
#
#           artists                                      artist_genres  \
# 0  ['Haftbefehl']                                 ['german hip hop']
# 1     ['Suchmos']  ['japanese r&b', 'j-rock', 'japanese soul', 'j...
# 2    ['Nilipek.']      ['turkish singer-songwriter', 'turkish rock']
# 3    ['Nilipek.']      ['turkish singer-songwriter', 'turkish rock']
# 4    ['Nilipek.']      ['turkish singer-songwriter', 'turkish rock']
#
#    duration  explicit                name
# 0    198746     False          Crackküche
# 1    408320     False               WATER
# ...

# %%
pd.merge(df_tracks, df_charts[["id", "country","artist_genres"]], on="id", how="left",validate="one_to_many")
# Out:
#                              id                                 name  \
# 0        35iwgR4jXetI318WEWsa1Q                                Carve
# 1        021ht4sdgPcrDgSk7JTbKY  Capítulo 2.16 - Banquero Anarquista
# 2        07A5yehtSnoedViJAZkNnc   Vivo para Quererte - Remasterizado
# 3        08FmqUhxtyLTn6pAh6bk45        El Prisionero - Remasterizado
# 4        08y9GfoqCWfOGsKdwojr5e                  Lady of the Evening
# ...                         ...                                  ...
# 3807629  27Y1N4Q4U3EfDU5Ubw8ws2            What They'll Say About Us
# 3807630  27Y1N4Q4U3EfDU5Ubw8ws2            What They'll Say About Us
# 3807631  27Y1N4Q4U3EfDU5Ubw8ws2            What They'll Say About Us
# 3807632  45XJsGpFTyzbzeWK8VzR8S                      A Day At A Time
# 3807633  5Ocn6dZ3BJFPWh4ylwFXtn                     Mar de Emociones
#
#          popularity  duration_ms  explicit                          artists  \
# ...

# %%
df_nuevo = pd.merge(df_tracks, df_charts[["id", "country","artist_genres"]], on="id", how="left",validate="one_to_many")
df_nuevo.head()
# Out:
#                        id                                 name  popularity  \
# 0  35iwgR4jXetI318WEWsa1Q                                Carve           6
# 1  021ht4sdgPcrDgSk7JTbKY  Capítulo 2.16 - Banquero Anarquista           0
# 2  07A5yehtSnoedViJAZkNnc   Vivo para Quererte - Remasterizado           0
# 3  08FmqUhxtyLTn6pAh6bk45        El Prisionero - Remasterizado           0
# 4  08y9GfoqCWfOGsKdwojr5e                  Lady of the Evening           0
#
#    duration_ms  explicit              artists                  id_artists  \
# 0       126903         0              ['Uli']  ['45tIt06XoI0Iio4LBEVpls']
# 1        98200         0  ['Fernando Pessoa']  ['14jtPCOoNZwquk5wd9DxrY']
# 2       181640         0  ['Ignacio Corsini']  ['5LiOoJbxVSAMkBS2fUm3X2']
# 3       176907         0  ['Ignacio Corsini']  ['5LiOoJbxVSAMkBS2fUm3X2']
# 4       163080         0      ['Dick Haymes']  ['3BiJGZsyX9sJchTqcSA7Su']
#
# ...

# %%
pd.merge(df_tracks, df_charts[["id", "country","artist_genres"]], on=df_tracks["id"], how="left")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_18832\2316443190.py in <module>
# ----> 1 pd.merge(df_tracks, df_charts[["id", "country","artist_genres"]], on=df_tracks["id"], how="left")
#
# c:\Users\mareg\anaconda3\envs\general\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     105     validate: str | None = None,
#     106 ) -> DataFrame:
# --> 107     op = _MergeOperation(
#     108         left,
#     109         right,
#
# c:\Users\mareg\anaconda3\envs\general\lib\site-packages\pandas\core\reshape\merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     698             self.right_join_keys,
#     699             self.join_names,
# ...

# %%
df_nuevo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3807634 entries, 0 to 3807633
# Data columns (total 22 columns):
#  #   Column            Dtype
# ---  ------            -----
#  0   id                object
#  1   name              object
#  2   popularity        int64
#  3   duration_ms       int64
#  4   explicit          int64
#  5   artists           object
#  6   id_artists        object
#  7   release_date      datetime64[ns]
#  8   danceability      float64
#  9   energy            float64
#  10  key               int64
#  11  loudness          float64
#  12  mode              int64
#  13  speechiness       float64
#  14  acousticness      float64
#  15  instrumentalness  float64
#  16  liveness          float64
#  17  valence           float64
#  18  tempo             float64
#  19  time_signature    int64
#  20  country           object
#  21  artist_genres     object
# dtypes: datetime64[ns](1), float64(9), int64(6), object(6)
# memory usage: 668.1+ MB

# %%
df_tracks.head()
# Out:
#                        id                                 name  popularity  \
# 0  35iwgR4jXetI318WEWsa1Q                                Carve           6
# 1  021ht4sdgPcrDgSk7JTbKY  Capítulo 2.16 - Banquero Anarquista           0
# 2  07A5yehtSnoedViJAZkNnc   Vivo para Quererte - Remasterizado           0
# 3  08FmqUhxtyLTn6pAh6bk45        El Prisionero - Remasterizado           0
# 4  08y9GfoqCWfOGsKdwojr5e                  Lady of the Evening           0
#
#    duration_ms  explicit              artists                  id_artists  \
# 0       126903         0              ['Uli']  ['45tIt06XoI0Iio4LBEVpls']
# 1        98200         0  ['Fernando Pessoa']  ['14jtPCOoNZwquk5wd9DxrY']
# 2       181640         0  ['Ignacio Corsini']  ['5LiOoJbxVSAMkBS2fUm3X2']
# 3       176907         0  ['Ignacio Corsini']  ['5LiOoJbxVSAMkBS2fUm3X2']
# 4       163080         0      ['Dick Haymes']  ['3BiJGZsyX9sJchTqcSA7Su']
#
# ...

# %%
df_nuevo.tail()
# Out:
#                              id                       name  popularity  \
# 3807629  27Y1N4Q4U3EfDU5Ubw8ws2  What They'll Say About Us          70
# 3807630  27Y1N4Q4U3EfDU5Ubw8ws2  What They'll Say About Us          70
# 3807631  27Y1N4Q4U3EfDU5Ubw8ws2  What They'll Say About Us          70
# 3807632  45XJsGpFTyzbzeWK8VzR8S            A Day At A Time          58
# 3807633  5Ocn6dZ3BJFPWh4ylwFXtn           Mar de Emociones          38
#
#          duration_ms  explicit                          artists  \
# 3807629       187601         0                      ['FINNEAS']
# 3807630       187601         0                      ['FINNEAS']
# 3807631       187601         0                      ['FINNEAS']
# 3807632       142003         0  ['Gentle Bones', 'Clara Benin']
# 3807633       214360         0                    ['Afrosound']
#
#                                                 id_artists release_date  \
# 3807629                         ['37M5pPGs6V1fchFJSgCguX']   2020-09-02
# ...

# %%
df_tracks.tail()
# Out:
#                             id                       name  popularity  \
# 586667  5rgu12WBIHQtvej2MdHSH0                        云与海          50
# 586668  0NuWgxEp51CutD2pJoF4OM                      blind          72
# 586669  27Y1N4Q4U3EfDU5Ubw8ws2  What They'll Say About Us          70
# 586670  45XJsGpFTyzbzeWK8VzR8S            A Day At A Time          58
# 586671  5Ocn6dZ3BJFPWh4ylwFXtn           Mar de Emociones          38
#
#         duration_ms  explicit                          artists  \
# 586667       258267         0                      ['阿YueYue']
# 586668       153293         0                   ['ROLE MODEL']
# 586669       187601         0                      ['FINNEAS']
# 586670       142003         0  ['Gentle Bones', 'Clara Benin']
# 586671       214360         0                    ['Afrosound']
#
#                                                id_artists release_date  \
# 586667                         ['1QLBXKM5GCpyQQSVMNZqrZ']   2020-09-26
# ...

# %%
df_nuevo.tail()
# Out:
#                              id                       name  popularity  \
# 3807629  27Y1N4Q4U3EfDU5Ubw8ws2  What They'll Say About Us          70
# 3807630  27Y1N4Q4U3EfDU5Ubw8ws2  What They'll Say About Us          70
# 3807631  27Y1N4Q4U3EfDU5Ubw8ws2  What They'll Say About Us          70
# 3807632  45XJsGpFTyzbzeWK8VzR8S            A Day At A Time          58
# 3807633  5Ocn6dZ3BJFPWh4ylwFXtn           Mar de Emociones          38
#
#          duration_ms  explicit                          artists  \
# 3807629       187601         0                      ['FINNEAS']
# 3807630       187601         0                      ['FINNEAS']
# 3807631       187601         0                      ['FINNEAS']
# 3807632       142003         0  ['Gentle Bones', 'Clara Benin']
# 3807633       214360         0                    ['Afrosound']
#
#                                                 id_artists release_date  \
# 3807629                         ['37M5pPGs6V1fchFJSgCguX']   2020-09-02
# ...

# %%
df_nuevo.loc[df_nuevo["country"]== "nan"]
# Out:
# Empty DataFrame
# Columns: [id, name, popularity, duration_ms, explicit, artists, id_artists, release_date, danceability, energy, key, loudness, mode, speechiness, acousticness, instrumentalness, liveness, valence, tempo, time_signature, country, artist_genres]
# Index: []
#
# [0 rows x 22 columns]

# %%
df_nuevo["country"].unique()
# Out:
# array([nan, 'global', 'us', 'gb', 'se', 'ca', 'de', 'nl', 'dk', 'au',
#        'no', 'ie', 'be', 'ch', 'nz', 'pl', 'at', 'hu', 'cz', 'fi', 'gr',
#        'sk', 'ro', 'is', 'pt', 'sg', 'lv', 'lt', 'es', 'ee', 'ph', 'lu',
#        'hk', 'my', 'mt', 'it', 'cy', 'za', 'ae', 'jp', 'bg', 'tw', 'kr',
#        'fr', 'mx', 'ru', 'cl', 'ua', 'vn', 'th', 'gt', 'ec', 'pe', 'cr',
#        'pa', 'hn', 'bo', 'ni', 'do', 'sv', 'ad', 'eg', 'id', 'ar', 'br',
#        'tr', 'co', 'uy', 'py', 'sa', 'il', 'in', 'ma', 'by', 've', 'pk',
#        'kz', 'ng'], dtype=object)

# %%
df_nuevo.shape
# Out:
# (3807634, 22)

# %%
df_nuevo.to_csv("marta_df.csv", index=False)

# %%
df_nuevo.isnull().sum()
# Out:
# id                       0
# name                    71
# popularity               0
# duration_ms              0
# explicit                 0
# artists                  0
# id_artists               0
# release_date             0
# danceability             0
# energy                   0
# key                      0
# loudness                 0
# mode                     0
# speechiness              0
# acousticness             0
# instrumentalness         0
# liveness                 0
# valence                  0
# tempo                    0
# time_signature           0
# country             559380
# artist_genres       559380
# dtype: int64

# %%
# %matplotlib inline
msno.matrix(df_nuevo.sample(25000))
# Out:
# <AxesSubplot:>

# %%
df_charts_grouped = df_charts.groupby("artist")[["country"]].first().reset_index()

# %%
df_nuevo["country"] = df_nuevo["country"].fillna(method="ffill")

# %%
df_nuevo_m= df_tracks.merge(df_charts, how='left', on='id')
df_nuevo_m.head()
# Out:
#                        id                               name_x  popularity  \
# 0  35iwgR4jXetI318WEWsa1Q                                Carve           6
# 1  021ht4sdgPcrDgSk7JTbKY  Capítulo 2.16 - Banquero Anarquista           0
# 2  07A5yehtSnoedViJAZkNnc   Vivo para Quererte - Remasterizado           0
# 3  08FmqUhxtyLTn6pAh6bk45        El Prisionero - Remasterizado           0
# 4  08y9GfoqCWfOGsKdwojr5e                  Lady of the Evening           0
#
#    duration_ms  explicit_x            artists_x                  id_artists  \
# 0       126903           0              ['Uli']  ['45tIt06XoI0Iio4LBEVpls']
# 1        98200           0  ['Fernando Pessoa']  ['14jtPCOoNZwquk5wd9DxrY']
# 2       181640           0  ['Ignacio Corsini']  ['5LiOoJbxVSAMkBS2fUm3X2']
# 3       176907           0  ['Ignacio Corsini']  ['5LiOoJbxVSAMkBS2fUm3X2']
# 4       163080           0      ['Dick Haymes']  ['3BiJGZsyX9sJchTqcSA7Su']
#
# ...

# %%
df_nuevo_m.shape
# Out:
# (3807634, 29)

# %%
df_nuevo_m.columns
# Out:
# Index(['id', 'name_x', 'popularity', 'duration_ms', 'explicit_x', 'artists_x',
#        'id_artists', 'release_date', 'danceability', 'energy', 'key',
#        'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness',
#        'liveness', 'valence', 'tempo', 'time_signature', 'date', 'country',
#        'position', 'streams', 'artists_y', 'artist_genres', 'duration',
#        'explicit_y', 'name_y'],
#       dtype='object')

# %%
print(df_nuevo_m['country'])
# Out:
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
#           ...
# 3807629     my
# 3807630     my
# 3807631     sg
# 3807632    NaN
# 3807633    NaN
# Name: country, Length: 3807634, dtype: object

# %%
df_nuevo_m = df_nuevo_m.drop(['artists_y', 'explicit_y',"duration","name_y"], axis=1)

# %%
df_nuevo_m.columns
# Out:
# Index(['id', 'name_x', 'popularity', 'duration_ms', 'explicit_x', 'artists_x',
#        'id_artists', 'release_date', 'danceability', 'energy', 'key',
#        'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness',
#        'liveness', 'valence', 'tempo', 'time_signature', 'date', 'country',
#        'position', 'streams', 'artist_genres'],
#       dtype='object')

# %%
df_nuevo_m.shape
# Out:
# (3807634, 25)

# %%
df_nuevo_m.head()
# Out:
#                        id                               name_x  popularity  \
# 0  35iwgR4jXetI318WEWsa1Q                                Carve           6
# 1  021ht4sdgPcrDgSk7JTbKY  Capítulo 2.16 - Banquero Anarquista           0
# 2  07A5yehtSnoedViJAZkNnc   Vivo para Quererte - Remasterizado           0
# 3  08FmqUhxtyLTn6pAh6bk45        El Prisionero - Remasterizado           0
# 4  08y9GfoqCWfOGsKdwojr5e                  Lady of the Evening           0
#
#    duration_ms  explicit_x            artists_x                  id_artists  \
# 0       126903           0              ['Uli']  ['45tIt06XoI0Iio4LBEVpls']
# 1        98200           0  ['Fernando Pessoa']  ['14jtPCOoNZwquk5wd9DxrY']
# 2       181640           0  ['Ignacio Corsini']  ['5LiOoJbxVSAMkBS2fUm3X2']
# 3       176907           0  ['Ignacio Corsini']  ['5LiOoJbxVSAMkBS2fUm3X2']
# 4       163080           0      ['Dick Haymes']  ['3BiJGZsyX9sJchTqcSA7Su']
#
# ...

# %%
df_nuevo_m = df_nuevo_m.dropna(thresh=1)

# %%
df_nuevo_m.shape
# Out:
# (3807634, 25)
