# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
from  matplotlib import pyplot as plt
import seaborn as sns
import missingno as msno
#import plotly.express as px

# %%
df1 = pd.read_csv(r"C:\Users\mareg\OneDrive\Escritorio\SPOTIFY CSV\archive (4)\tracks.csv", encoding = "UTF-8",parse_dates=['release_date'])
df1.head()
# Out:
#                        id                                 name  popularity  \
# 0  35iwgR4jXetI318WEWsa1Q                                Carve           6
# 1  021ht4sdgPcrDgSk7JTbKY  Capítulo 2.16 - Banquero Anarquista           0
# 2  07A5yehtSnoedViJAZkNnc   Vivo para Quererte - Remasterizado           0
# 3  08FmqUhxtyLTn6pAh6bk45        El Prisionero - Remasterizado           0
# 4  08y9GfoqCWfOGsKdwojr5e                  Lady of the Evening           0
#
#    duration_ms  explicit              artists                  id_artists  \
# 0       126903         0              ['Uli']  ['45tIt06XoI0Iio4LBEVpls']
# 1        98200         0  ['Fernando Pessoa']  ['14jtPCOoNZwquk5wd9DxrY']
# 2       181640         0  ['Ignacio Corsini']  ['5LiOoJbxVSAMkBS2fUm3X2']
# 3       176907         0  ['Ignacio Corsini']  ['5LiOoJbxVSAMkBS2fUm3X2']
# 4       163080         0      ['Dick Haymes']  ['3BiJGZsyX9sJchTqcSA7Su']
#
#   release_date  danceability  energy  key  loudness  mode  speechiness  \
# 0   1922-02-22         0.645  0.4450    0   -13.338     1       0.4510
# 1   1922-06-01         0.695  0.2630    0   -22.136     1       0.9570
# 2   1922-03-21         0.434  0.1770    1   -21.180     1       0.0512
# 3   1922-03-21         0.321  0.0946    7   -27.961     1       0.0504
# 4   1922-01-01         0.402  0.1580    3   -16.900     0       0.0390
#
#    acousticness  instrumentalness  liveness  valence    tempo  time_signature
# 0         0.674            0.7440     0.151    0.127  104.851               3
# 1         0.797            0.0000     0.148    0.655  102.009               1
# 2         0.994            0.0218     0.212    0.457  130.418               5
# 3         0.995            0.9180     0.104    0.397  169.980               3
# 4         0.989            0.1300     0.311    0.196  103.220               4

# %%
df1.shape
# Out:
# (586672, 20)

# %%
merged_df.shape
# Out:
# (586672, 29)

# %%
merged_df.isnull().sum()
# Out:
# id                       0
# name_x                  71
# popularity               0
# duration_ms              0
# explicit_x               0
# artists_x                0
# id_artists               0
# release_date             0
# danceability             0
# energy                   0
# key                      0
# loudness                 0
# mode                     0
# speechiness              0
# acousticness             0
# instrumentalness         0
# liveness                 0
# valence                  0
# tempo                    0
# time_signature           0
# date                559380
# country             559380
# position            559380
# streams             559380
# artists_y           559380
# artist_genres       559380
# duration            559380
# explicit_y          559380
# name_y              559386
# dtype: int64

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 586672 entries, 0 to 586671
# Data columns (total 20 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   id                586672 non-null  object
#  1   name              586601 non-null  object
#  2   popularity        586672 non-null  int64
#  3   duration_ms       586672 non-null  int64
#  4   explicit          586672 non-null  int64
#  5   artists           586672 non-null  object
#  6   id_artists        586672 non-null  object
#  7   release_date      586672 non-null  datetime64[ns]
#  8   danceability      586672 non-null  float64
#  9   energy            586672 non-null  float64
#  10  key               586672 non-null  int64
#  11  loudness          586672 non-null  float64
#  12  mode              586672 non-null  int64
#  13  speechiness       586672 non-null  float64
#  14  acousticness      586672 non-null  float64
#  15  instrumentalness  586672 non-null  float64
#  16  liveness          586672 non-null  float64
#  17  valence           586672 non-null  float64
#  18  tempo             586672 non-null  float64
#  19  time_signature    586672 non-null  int64
# dtypes: datetime64[ns](1), float64(9), int64(6), object(4)
# memory usage: 89.5+ MB

# %%
df1_copia = df1.copy()

# %%
 df1_copia = df1_copia.drop_duplicates(
  subset = ['name', 'artists', "id"],
  keep = 'last').reset_index(drop = True)
df1_copia
# Out:
#                             id                                 name  \
# 0       35iwgR4jXetI318WEWsa1Q                                Carve
# 1       021ht4sdgPcrDgSk7JTbKY  Capítulo 2.16 - Banquero Anarquista
# 2       07A5yehtSnoedViJAZkNnc   Vivo para Quererte - Remasterizado
# 3       08FmqUhxtyLTn6pAh6bk45        El Prisionero - Remasterizado
# 4       08y9GfoqCWfOGsKdwojr5e                  Lady of the Evening
# ...                        ...                                  ...
# 586667  5rgu12WBIHQtvej2MdHSH0                                  云与海
# 586668  0NuWgxEp51CutD2pJoF4OM                                blind
# 586669  27Y1N4Q4U3EfDU5Ubw8ws2            What They'll Say About Us
# 586670  45XJsGpFTyzbzeWK8VzR8S                      A Day At A Time
# 586671  5Ocn6dZ3BJFPWh4ylwFXtn                     Mar de Emociones
#
#         popularity  duration_ms  explicit                          artists  \
# 0                6       126903         0                          ['Uli']
# 1                0        98200         0              ['Fernando Pessoa']
# 2                0       181640         0              ['Ignacio Corsini']
# 3                0       176907         0              ['Ignacio Corsini']
# 4                0       163080         0                  ['Dick Haymes']
# ...            ...          ...       ...                              ...
# 586667          50       258267         0                      ['阿YueYue']
# 586668          72       153293         0                   ['ROLE MODEL']
# 586669          70       187601         0                      ['FINNEAS']
# 586670          58       142003         0  ['Gentle Bones', 'Clara Benin']
# 586671          38       214360         0                    ['Afrosound']
#
#                                                id_artists release_date  \
# 0                              ['45tIt06XoI0Iio4LBEVpls']   1922-02-22
# 1                              ['14jtPCOoNZwquk5wd9DxrY']   1922-06-01
# 2                              ['5LiOoJbxVSAMkBS2fUm3X2']   1922-03-21
# 3                              ['5LiOoJbxVSAMkBS2fUm3X2']   1922-03-21
# 4                              ['3BiJGZsyX9sJchTqcSA7Su']   1922-01-01
# ...                                                   ...          ...
# 586667                         ['1QLBXKM5GCpyQQSVMNZqrZ']   2020-09-26
# 586668                         ['1dy5WNgIKQU6ezkpZs4y8z']   2020-10-21
# 586669                         ['37M5pPGs6V1fchFJSgCguX']   2020-09-02
# 586670  ['4jGPdu95icCKVF31CcFKbS', '5ebPSE9YI5aLeZ1Z2g...   2021-03-05
# 586671                         ['0i4Qda0k4nf7jnNHmSNpYv']   2015-07-01
#
#         danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0              0.645  0.4450    0   -13.338     1       0.4510         0.674
# 1              0.695  0.2630    0   -22.136     1       0.9570         0.797
# 2              0.434  0.1770    1   -21.180     1       0.0512         0.994
# 3              0.321  0.0946    7   -27.961     1       0.0504         0.995
# 4              0.402  0.1580    3   -16.900     0       0.0390         0.989
# ...              ...     ...  ...       ...   ...          ...           ...
# 586667         0.560  0.5180    0    -7.471     0       0.0292         0.785
# 586668         0.765  0.6630    0    -5.223     1       0.0652         0.141
# 586669         0.535  0.3140    7   -12.823     0       0.0408         0.895
# 586670         0.696  0.6150   10    -6.212     1       0.0345         0.206
# 586671         0.686  0.7230    6    -7.067     1       0.0363         0.105
#
#         instrumentalness  liveness  valence    tempo  time_signature
# 0               0.744000    0.1510   0.1270  104.851               3
# 1               0.000000    0.1480   0.6550  102.009               1
# 2               0.021800    0.2120   0.4570  130.418               5
# 3               0.918000    0.1040   0.3970  169.980               3
# 4               0.130000    0.3110   0.1960  103.220               4
# ...                  ...       ...      ...      ...             ...
# 586667          0.000000    0.0648   0.2110  131.896               4
# 586668          0.000297    0.0924   0.6860  150.091               4
# 586669          0.000150    0.0874   0.0663  145.095               4
# 586670          0.000003    0.3050   0.4380   90.029               4
# 586671          0.000000    0.2640   0.9750  112.204               4
#
# [586672 rows x 20 columns]

# %%
df2 = pd.read_csv(r"C:\Users\mareg\Downloads\archive (6)\charts.csv", encoding = "UTF-8")
df2.head()
# Out:
#          date country  position  streams                track_id  \
# 0  2021/04/15      de        82   625718  20IvMlpi4U5RuDnAlXSRiV
# 1  2019/01/31      jp       171    50896  0V1K6MU0utODk4yNqZKsFv
# 2  2018/11/15      tr        59   185439  4qzZm5EIdFurBpDieEmVc9
# 3  2018/11/22      tr       133   111159  4qzZm5EIdFurBpDieEmVc9
# 4  2018/11/29      tr       166    96204  4qzZm5EIdFurBpDieEmVc9
#
#           artists                                      artist_genres  \
# 0  ['Haftbefehl']                                 ['german hip hop']
# 1     ['Suchmos']  ['japanese r&b', 'j-rock', 'japanese soul', 'j...
# 2    ['Nilipek.']      ['turkish singer-songwriter', 'turkish rock']
# 3    ['Nilipek.']      ['turkish singer-songwriter', 'turkish rock']
# 4    ['Nilipek.']      ['turkish singer-songwriter', 'turkish rock']
#
#    duration  explicit                name
# 0    198746     False          Crackküche
# 1    408320     False               WATER
# 2    257142     False  Gözleri Aşka Gülen
# 3    257142     False  Gözleri Aşka Gülen
# 4    257142     False  Gözleri Aşka Gülen

# %%
df2.columns
# Out:
# Index(['date', 'country', 'position', 'streams', 'track_id', 'artists',
#        'artist_genres', 'duration', 'explicit', 'name'],
#       dtype='object')

# %%
df2.shape
# Out:
# (5428021, 10)

# %%
df2_copia= df2.copy()

# %%
df2_copia = df2.rename(columns={'track_id': 'id'})
df2_copia.head()
# Out:
#          date country  position  streams                      id  \
# 0  2021/04/15      de        82   625718  20IvMlpi4U5RuDnAlXSRiV
# 1  2019/01/31      jp       171    50896  0V1K6MU0utODk4yNqZKsFv
# 2  2018/11/15      tr        59   185439  4qzZm5EIdFurBpDieEmVc9
# 3  2018/11/22      tr       133   111159  4qzZm5EIdFurBpDieEmVc9
# 4  2018/11/29      tr       166    96204  4qzZm5EIdFurBpDieEmVc9
#
#           artists                                      artist_genres  \
# 0  ['Haftbefehl']                                 ['german hip hop']
# 1     ['Suchmos']  ['japanese r&b', 'j-rock', 'japanese soul', 'j...
# 2    ['Nilipek.']      ['turkish singer-songwriter', 'turkish rock']
# 3    ['Nilipek.']      ['turkish singer-songwriter', 'turkish rock']
# 4    ['Nilipek.']      ['turkish singer-songwriter', 'turkish rock']
#
#    duration  explicit                name
# 0    198746     False          Crackküche
# 1    408320     False               WATER
# 2    257142     False  Gözleri Aşka Gülen
# 3    257142     False  Gözleri Aşka Gülen
# 4    257142     False  Gözleri Aşka Gülen

# %%
df2_copia = df2_copia.drop_duplicates(
  subset = ['name', 'artists', "id"],
  keep = 'last').reset_index(drop = True)
df1_copia
# Out:
#                             id                                 name  \
# 0       35iwgR4jXetI318WEWsa1Q                                Carve
# 1       021ht4sdgPcrDgSk7JTbKY  Capítulo 2.16 - Banquero Anarquista
# 2       07A5yehtSnoedViJAZkNnc   Vivo para Quererte - Remasterizado
# 3       08FmqUhxtyLTn6pAh6bk45        El Prisionero - Remasterizado
# 4       08y9GfoqCWfOGsKdwojr5e                  Lady of the Evening
# ...                        ...                                  ...
# 586667  5rgu12WBIHQtvej2MdHSH0                                  云与海
# 586668  0NuWgxEp51CutD2pJoF4OM                                blind
# 586669  27Y1N4Q4U3EfDU5Ubw8ws2            What They'll Say About Us
# 586670  45XJsGpFTyzbzeWK8VzR8S                      A Day At A Time
# 586671  5Ocn6dZ3BJFPWh4ylwFXtn                     Mar de Emociones
#
#         popularity  duration_ms  explicit                          artists  \
# 0                6       126903         0                          ['Uli']
# 1                0        98200         0              ['Fernando Pessoa']
# 2                0       181640         0              ['Ignacio Corsini']
# 3                0       176907         0              ['Ignacio Corsini']
# 4                0       163080         0                  ['Dick Haymes']
# ...            ...          ...       ...                              ...
# 586667          50       258267         0                      ['阿YueYue']
# 586668          72       153293         0                   ['ROLE MODEL']
# 586669          70       187601         0                      ['FINNEAS']
# 586670          58       142003         0  ['Gentle Bones', 'Clara Benin']
# 586671          38       214360         0                    ['Afrosound']
#
#                                                id_artists release_date  \
# 0                              ['45tIt06XoI0Iio4LBEVpls']   1922-02-22
# 1                              ['14jtPCOoNZwquk5wd9DxrY']   1922-06-01
# 2                              ['5LiOoJbxVSAMkBS2fUm3X2']   1922-03-21
# 3                              ['5LiOoJbxVSAMkBS2fUm3X2']   1922-03-21
# 4                              ['3BiJGZsyX9sJchTqcSA7Su']   1922-01-01
# ...                                                   ...          ...
# 586667                         ['1QLBXKM5GCpyQQSVMNZqrZ']   2020-09-26
# 586668                         ['1dy5WNgIKQU6ezkpZs4y8z']   2020-10-21
# 586669                         ['37M5pPGs6V1fchFJSgCguX']   2020-09-02
# 586670  ['4jGPdu95icCKVF31CcFKbS', '5ebPSE9YI5aLeZ1Z2g...   2021-03-05
# 586671                         ['0i4Qda0k4nf7jnNHmSNpYv']   2015-07-01
#
#         danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0              0.645  0.4450    0   -13.338     1       0.4510         0.674
# 1              0.695  0.2630    0   -22.136     1       0.9570         0.797
# 2              0.434  0.1770    1   -21.180     1       0.0512         0.994
# 3              0.321  0.0946    7   -27.961     1       0.0504         0.995
# 4              0.402  0.1580    3   -16.900     0       0.0390         0.989
# ...              ...     ...  ...       ...   ...          ...           ...
# 586667         0.560  0.5180    0    -7.471     0       0.0292         0.785
# 586668         0.765  0.6630    0    -5.223     1       0.0652         0.141
# 586669         0.535  0.3140    7   -12.823     0       0.0408         0.895
# 586670         0.696  0.6150   10    -6.212     1       0.0345         0.206
# 586671         0.686  0.7230    6    -7.067     1       0.0363         0.105
#
#         instrumentalness  liveness  valence    tempo  time_signature
# 0               0.744000    0.1510   0.1270  104.851               3
# 1               0.000000    0.1480   0.6550  102.009               1
# 2               0.021800    0.2120   0.4570  130.418               5
# 3               0.918000    0.1040   0.3970  169.980               3
# 4               0.130000    0.3110   0.1960  103.220               4
# ...                  ...       ...      ...      ...             ...
# 586667          0.000000    0.0648   0.2110  131.896               4
# 586668          0.000297    0.0924   0.6860  150.091               4
# 586669          0.000150    0.0874   0.0663  145.095               4
# 586670          0.000003    0.3050   0.4380   90.029               4
# 586671          0.000000    0.2640   0.9750  112.204               4
#
# [586672 rows x 20 columns]

# %% [markdown]
# No lo ejecuto

# %%
#Eliminamos la columna C del segundo DataFrame

df2 =df2.drop("name", axis=1)
df2 =df2.drop("artists", axis=1)
df2 =df2.drop("explicit", axis=1)
df2 =df2.drop("position", axis=1)
df2 =df2.drop("streams", axis=1)
df2 =df2.drop("date", axis=1)
print(df2)
# Realizamos el merge por la columna A
#merged_df = pd.merge(df1, df2, on='A', how='left', suffixes=('_x', '_y'))

# Imprimimos el resultado
#print(merged_df)
# Out:
#         country                track_id  \
# 0            de  20IvMlpi4U5RuDnAlXSRiV
# 1            jp  0V1K6MU0utODk4yNqZKsFv
# 2            tr  4qzZm5EIdFurBpDieEmVc9
# 3            tr  4qzZm5EIdFurBpDieEmVc9
# 4            tr  4qzZm5EIdFurBpDieEmVc9
# ...         ...                     ...
# 5428016      se  7731grGgxDd7aBNpGOjm9k
# 5428017      jp  4Vm9XIi9AD1oK39xACmqk5
# 5428018      jp  4Vm9XIi9AD1oK39xACmqk5
# 5428019      jp  4Vm9XIi9AD1oK39xACmqk5
# 5428020      dk  1selIVe40h0Ak2GVCzg5si
#
#                                              artist_genres
# 0                                       ['german hip hop']
# 1        ['japanese r&b', 'j-rock', 'japanese soul', 'j...
# 2            ['turkish singer-songwriter', 'turkish rock']
# 3            ['turkish singer-songwriter', 'turkish rock']
# 4            ['turkish singer-songwriter', 'turkish rock']
# ...                                                    ...
# 5428016                       ['swedish alternative rock']
# 5428017  ['j-poprock', 'anime', 'j-rock', 'japanese ind...
# 5428018  ['j-poprock', 'anime', 'j-rock', 'japanese ind...
# 5428019  ['j-poprock', 'anime', 'j-rock', 'japanese ind...
# 5428020                   ['danish pop', 'danish hip hop']
#
# [5428021 rows x 3 columns]

# %%
df2_copia.isnull().sum()
# Out:
# date              0
# country           0
# position          0
# streams           0
# id                0
# artists           0
# artist_genres     0
# duration          0
# explicit          0
# name             94
# dtype: int64

# %%
df2_copia.shape
# Out:
# (110292, 10)

# %%
merged_df = pd.merge(df1_copia, df2_copia, on='id', how='left', suffixes=('_x', '_y'))

# %%
#merged_df = pd.merge(df1, df2[['key', 'id', 'country', 'artist_genres']], on='id')

# %%
merged_df.head()
# Out:
#                        id                               name_x  popularity  \
# 0  35iwgR4jXetI318WEWsa1Q                                Carve           6
# 1  021ht4sdgPcrDgSk7JTbKY  Capítulo 2.16 - Banquero Anarquista           0
# 2  07A5yehtSnoedViJAZkNnc   Vivo para Quererte - Remasterizado           0
# 3  08FmqUhxtyLTn6pAh6bk45        El Prisionero - Remasterizado           0
# 4  08y9GfoqCWfOGsKdwojr5e                  Lady of the Evening           0
#
#    duration_ms  explicit_x            artists_x                  id_artists  \
# 0       126903           0              ['Uli']  ['45tIt06XoI0Iio4LBEVpls']
# 1        98200           0  ['Fernando Pessoa']  ['14jtPCOoNZwquk5wd9DxrY']
# 2       181640           0  ['Ignacio Corsini']  ['5LiOoJbxVSAMkBS2fUm3X2']
# 3       176907           0  ['Ignacio Corsini']  ['5LiOoJbxVSAMkBS2fUm3X2']
# 4       163080           0      ['Dick Haymes']  ['3BiJGZsyX9sJchTqcSA7Su']
#
#   release_date  danceability  energy  ...  time_signature  date  country  \
# 0   1922-02-22         0.645  0.4450  ...               3   NaN      NaN
# 1   1922-06-01         0.695  0.2630  ...               1   NaN      NaN
# 2   1922-03-21         0.434  0.1770  ...               5   NaN      NaN
# 3   1922-03-21         0.321  0.0946  ...               3   NaN      NaN
# 4   1922-01-01         0.402  0.1580  ...               4   NaN      NaN
#
#    position  streams  artists_y  artist_genres  duration  explicit_y  name_y
# 0       NaN      NaN        NaN            NaN       NaN         NaN     NaN
# 1       NaN      NaN        NaN            NaN       NaN         NaN     NaN
# 2       NaN      NaN        NaN            NaN       NaN         NaN     NaN
# 3       NaN      NaN        NaN            NaN       NaN         NaN     NaN
# 4       NaN      NaN        NaN            NaN       NaN         NaN     NaN
#
# [5 rows x 29 columns]

# %%
merged_df.shape
# Out:
# (586672, 29)

# %%
merged_df.isnull().sum()
# Out:
# id                       0
# name_x                  71
# popularity               0
# duration_ms              0
# explicit_x               0
# artists_x                0
# id_artists               0
# release_date             0
# danceability             0
# energy                   0
# key                      0
# loudness                 0
# mode                     0
# speechiness              0
# acousticness             0
# instrumentalness         0
# liveness                 0
# valence                  0
# tempo                    0
# time_signature           0
# date                559380
# country             559380
# position            559380
# streams             559380
# artists_y           559380
# artist_genres       559380
# duration            559380
# explicit_y          559380
# name_y              559386
# dtype: int64

# %%
df_nuevo["country"].unique()
# Out:
# array([nan, 'global', 'us', 'gb', 'se', 'ca', 'de', 'nl', 'dk', 'au',
#        'no', 'ie', 'be', 'ch', 'nz', 'pl', 'at', 'hu', 'cz', 'fi', 'gr',
#        'sk', 'ro', 'is', 'pt', 'sg', 'lv', 'lt', 'es', 'ee', 'ph', 'lu',
#        'hk', 'my', 'mt', 'it', 'cy', 'za', 'ae', 'jp', 'bg', 'tw', 'kr',
#        'fr', 'mx', 'ru', 'cl', 'ua', 'vn', 'th', 'gt', 'ec', 'pe', 'cr',
#        'pa', 'hn', 'bo', 'ni', 'do', 'sv', 'ad', 'eg', 'id', 'ar', 'br',
#        'tr', 'co', 'uy', 'py', 'sa', 'il', 'in', 'ma', 'by', 've', 'pk',
#        'kz', 'ng'], dtype=object)

# %%
# %matplotlib inline
msno.matrix(merged_df.sample(25000))
# Out:
# <AxesSubplot:>

# %%
df_charts_grouped = df_charts.groupby("artist")[["country"]].first().reset_index()

# %%
df_nuevo["country"] = df_nuevo["country"].fillna(method="ffill")

# %%
df_nuevo = pd.merge(df_tracks, df_charts[["id", "country","artist_genres"]], on="id",validate="one_to_many")
df_nuevo.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3160\2441342785.py in <module>
# ----> 1 df_nuevo = pd.merge(df_tracks, df_charts[["id", "country","artist_genres"]], on="id",validate="one_to_many")
#       2 df_nuevo.head()
#
# NameError: name 'pd' is not defined

# %%
df_nuevo2 = pd.merge(df_tracks, df_charts, on="id")
df_nuevo2.head()
# Out:
#                        id           name_x  popularity  duration_ms  \
# 0  4so0Wek9Ig1p6CRCHuINwW  White Christmas          56       177480
# 1  4so0Wek9Ig1p6CRCHuINwW  White Christmas          56       177480
# 2  4so0Wek9Ig1p6CRCHuINwW  White Christmas          56       177480
# 3  4so0Wek9Ig1p6CRCHuINwW  White Christmas          56       177480
# 4  4so0Wek9Ig1p6CRCHuINwW  White Christmas          56       177480
#
#    explicit_x                                          artists_x  \
# 0           0  ['Bing Crosby', 'Ken Darby Singers', 'John Sco...
# 1           0  ['Bing Crosby', 'Ken Darby Singers', 'John Sco...
# 2           0  ['Bing Crosby', 'Ken Darby Singers', 'John Sco...
# 3           0  ['Bing Crosby', 'Ken Darby Singers', 'John Sco...
# 4           0  ['Bing Crosby', 'Ken Darby Singers', 'John Sco...
#
#                                           id_artists release_date  \
# 0  ['6ZjFtWeHP9XN7FeKSUe80S', '69UfPJgUmFFAVT740q...   1942-01-01
# 1  ['6ZjFtWeHP9XN7FeKSUe80S', '69UfPJgUmFFAVT740q...   1942-01-01
# 2  ['6ZjFtWeHP9XN7FeKSUe80S', '69UfPJgUmFFAVT740q...   1942-01-01
# 3  ['6ZjFtWeHP9XN7FeKSUe80S', '69UfPJgUmFFAVT740q...   1942-01-01
# 4  ['6ZjFtWeHP9XN7FeKSUe80S', '69UfPJgUmFFAVT740q...   1942-01-01
#
#    danceability  energy  ...        date  country  position  streams  \
# 0         0.317   0.158  ...  2015/12/10   global       161  1915603
# 1         0.317   0.158  ...  2015/12/17   global       135  2227464
# 2         0.317   0.158  ...  2015/12/24   global        78  3587825
# 3         0.317   0.158  ...  2016/12/01   global       194  2373547
# 4         0.317   0.158  ...  2016/12/08   global       141  3504835
#
#                                            artists_y  \
# 0  ['Bing Crosby', 'Ken Darby Singers', 'John Sco...
# 1  ['Bing Crosby', 'Ken Darby Singers', 'John Sco...
# 2  ['Bing Crosby', 'Ken Darby Singers', 'John Sco...
# 3  ['Bing Crosby', 'Ken Darby Singers', 'John Sco...
# 4  ['Bing Crosby', 'Ken Darby Singers', 'John Sco...
#
#                                        artist_genres  duration  explicit_y  \
# 0  ['easy listening', 'adult standards', 'lounge'...    177480       False
# 1  ['easy listening', 'adult standards', 'lounge'...    177480       False
# 2  ['easy listening', 'adult standards', 'lounge'...    177480       False
# 3  ['easy listening', 'adult standards', 'lounge'...    177480       False
# 4  ['easy listening', 'adult standards', 'lounge'...    177480       False
#
#             name_y    key_y
# 0  White Christmas  2769260
# 1  White Christmas  2769261
# 2  White Christmas  2769262
# 3  White Christmas  2769263
# 4  White Christmas  2769264
#
# [5 rows x 30 columns]

# %%
df_nuevosin = df_nuevo2.drop_duplicates(subset=['id'])

# %%
df_nuevosin.shape
# Out:
# (27292, 30)

# %%
years = df_nuevosin.release_date.dt.year
years
# Out:
# 0          1942
# 753        1944
# 796        1945
# 812        1945
# 863        1945
#            ...
# 3248009    2018
# 3248201    2019
# 3248219    2019
# 3248235    2020
# 3248249    2020
# Name: release_date, Length: 27292, dtype: int64

# %%
df_nuevosin['years'] = years
df_nuevosin.head()
# Out:
# C:\Users\mareg\AppData\Local\Temp\ipykernel_14976\3879599519.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_nuevosin['years'] = years
#                          id                                  name_x  \
# 0    4so0Wek9Ig1p6CRCHuINwW                         White Christmas
# 753  030mot3ZKR3oskfMsqDB2R  Have Yourself A Merry Little Christmas
# 796  04vLj9QUXoKdRlsp3gkURo       Mele Kalikimaka (Merry Christmas)
# 812  44mYhOVgerj2qPjkGDVA6n   It's Beginning To Look Like Christmas
# 863  7ehhnVu3JUWMaSJzY1zC4k                            Silver Bells
#
#      popularity  duration_ms  explicit_x  \
# 0            56       177480           0
# 753          50       162333           0
# 796          41       175333           0
# 812          37       166000           0
# 863          25       182667           0
#
#                                              artists_x  \
# 0    ['Bing Crosby', 'Ken Darby Singers', 'John Sco...
# 753                                   ['Judy Garland']
# 796             ['Bing Crosby', 'The Andrews Sisters']
# 812                                    ['Bing Crosby']
# 863                  ['Bing Crosby', 'Carol Richards']
#
#                                             id_artists release_date  \
# 0    ['6ZjFtWeHP9XN7FeKSUe80S', '69UfPJgUmFFAVT740q...   1942-01-01
# 753                         ['0hItVPjwJLVZrFqOyIsxPf']   1944-01-01
# 796  ['6ZjFtWeHP9XN7FeKSUe80S', '2NCGI6dLTxLdI9XHdv...   1945-01-01
# 812                         ['6ZjFtWeHP9XN7FeKSUe80S']   1945-01-01
# 863  ['6ZjFtWeHP9XN7FeKSUe80S', '0Im4XjInyfMuA2lVka...   1945-01-01
#
#      danceability  energy  ...  country  position  streams  \
# 0           0.317   0.158  ...   global       161  1915603
# 753         0.156   0.184  ...       us       175  1937798
# 796         0.500   0.224  ...       us       134  2308499
# 812         0.473   0.212  ...   global       134  6892613
# 863         0.343   0.136  ...       us       193  1672731
#
#                                              artists_y  \
# 0    ['Bing Crosby', 'Ken Darby Singers', 'John Sco...
# 753                                   ['Judy Garland']
# 796             ['Bing Crosby', 'The Andrews Sisters']
# 812                                    ['Bing Crosby']
# 863                  ['Bing Crosby', 'Carol Richards']
#
#                                          artist_genres  duration  explicit_y  \
# 0    ['easy listening', 'adult standards', 'lounge'...    177480       False
# 753  ['torch song', 'adult standards', 'lounge', 'h...    162333       False
# 796  ['torch song', 'adult standards', 'swing', 'lo...    175333       False
# 812    ['easy listening', 'lounge', 'adult standards']    166000       False
# 863    ['easy listening', 'adult standards', 'lounge']    182666       False
#
#                                      name_y    key_y  years
# 0                           White Christmas  2769260   1942
# 753  Have Yourself A Merry Little Christmas   205191   1944
# 796       Mele Kalikimaka (Merry Christmas)  3939117   1945
# 812   It's Beginning To Look Like Christmas  5278981   1945
# 863                            Silver Bells  4903058   1945
#
# [5 rows x 31 columns]

# %%
num_tracks_by_year = df_nuevosin.groupby(df_nuevosin.release_date.dt.year)['release_date'].count()
num_tracks_by_year
# Out:
# release_date
# 1942       1
# 1944       1
# 1945       3
# 1946       1
# 1947       2
#         ...
# 2017    2226
# 2018    3339
# 2019    4705
# 2020    5761
# 2021    2264
# Name: release_date, Length: 74, dtype: int64

# %%
num_tracks_by_tempo = df_nuevosin.groupby('years')['tempo'].mean()
num_tracks_by_tempo
# Out:
# years
# 1942    130.503000
# 1944    180.887000
# 1945    123.452667
# 1946     80.755000
# 1947    119.392500
#            ...
# 2017    121.756310
# 2018    122.435076
# 2019    122.074389
# 2020    122.102914
# 2021    122.397448
# Name: tempo, Length: 74, dtype: float64

# %%
years = num_tracks_by_year.index.tolist()
country = num.values.tolist()

plt.bar(years, country, width=0.8, color = "blue")
plt.title('Canciones lanzadas al mercado por año')
plt.xlabel('Year')
plt.ylabel('Number of tracks')
plt.xlim(1920, 2022)
plt.xticks(range(1920, 2022, 10), rotation=90)
plt.ylim([0, max(country)+100])

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14976\467176012.py in <module>
#       1 years = num_tracks_by_year.index.tolist()
# ----> 2 country = num_tracks_by_country.values.tolist()
#       3
#       4 plt.bar(years, country, width=0.8, color = "blue")
#       5 plt.title('Canciones lanzadas al mercado por año')
#
# NameError: name 'num_tracks_by_country' is not defined

# %%
df_nuevosin.head()
# Out:
#                          id                                  name_x  \
# 0    4so0Wek9Ig1p6CRCHuINwW                         White Christmas
# 753  030mot3ZKR3oskfMsqDB2R  Have Yourself A Merry Little Christmas
# 796  04vLj9QUXoKdRlsp3gkURo       Mele Kalikimaka (Merry Christmas)
# 812  44mYhOVgerj2qPjkGDVA6n   It's Beginning To Look Like Christmas
# 863  7ehhnVu3JUWMaSJzY1zC4k                            Silver Bells
#
#      popularity  duration_ms  explicit_x  \
# 0            56       177480           0
# 753          50       162333           0
# 796          41       175333           0
# 812          37       166000           0
# 863          25       182667           0
#
#                                              artists_x  \
# 0    ['Bing Crosby', 'Ken Darby Singers', 'John Sco...
# 753                                   ['Judy Garland']
# 796             ['Bing Crosby', 'The Andrews Sisters']
# 812                                    ['Bing Crosby']
# 863                  ['Bing Crosby', 'Carol Richards']
#
#                                             id_artists release_date  \
# 0    ['6ZjFtWeHP9XN7FeKSUe80S', '69UfPJgUmFFAVT740q...   1942-01-01
# 753                         ['0hItVPjwJLVZrFqOyIsxPf']   1944-01-01
# 796  ['6ZjFtWeHP9XN7FeKSUe80S', '2NCGI6dLTxLdI9XHdv...   1945-01-01
# 812                         ['6ZjFtWeHP9XN7FeKSUe80S']   1945-01-01
# 863  ['6ZjFtWeHP9XN7FeKSUe80S', '0Im4XjInyfMuA2lVka...   1945-01-01
#
#      danceability  energy  ...        date  country  position  streams  \
# 0           0.317   0.158  ...  2015/12/10   global       161  1915603
# 753         0.156   0.184  ...  2019/12/19       us       175  1937798
# 796         0.500   0.224  ...  2018/12/27       us       134  2308499
# 812         0.473   0.212  ...  2019/12/26   global       134  6892613
# 863         0.343   0.136  ...  2021/12/09       us       193  1672731
#
#                                              artists_y  \
# 0    ['Bing Crosby', 'Ken Darby Singers', 'John Sco...
# 753                                   ['Judy Garland']
# 796             ['Bing Crosby', 'The Andrews Sisters']
# 812                                    ['Bing Crosby']
# 863                  ['Bing Crosby', 'Carol Richards']
#
#                                          artist_genres  duration  explicit_y  \
# 0    ['easy listening', 'adult standards', 'lounge'...    177480       False
# 753  ['torch song', 'adult standards', 'lounge', 'h...    162333       False
# 796  ['torch song', 'adult standards', 'swing', 'lo...    175333       False
# 812    ['easy listening', 'lounge', 'adult standards']    166000       False
# 863    ['easy listening', 'adult standards', 'lounge']    182666       False
#
#                                      name_y    key_y
# 0                           White Christmas  2769260
# 753  Have Yourself A Merry Little Christmas   205191
# 796       Mele Kalikimaka (Merry Christmas)  3939117
# 812   It's Beginning To Look Like Christmas  5278981
# 863                            Silver Bells  4903058
#
# [5 rows x 30 columns]

# %%
merged_df = pd.merge(df1, df2, on='ID')
print(merged_df)
