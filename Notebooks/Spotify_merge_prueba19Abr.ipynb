# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
from  matplotlib import pyplot as plt
import seaborn as sns
import missingno as msno
#import plotly.express as px

# %%
df1 = pd.read_csv(r"C:\Users\mareg\OneDrive\Escritorio\SPOTIFY CSV\archive (4)\tracks.csv", encoding = "UTF-8",parse_dates=['release_date'])
df1.head()
# Out:
#                        id                                 name  popularity  \
# 0  35iwgR4jXetI318WEWsa1Q                                Carve           6
# 1  021ht4sdgPcrDgSk7JTbKY  Capítulo 2.16 - Banquero Anarquista           0
# 2  07A5yehtSnoedViJAZkNnc   Vivo para Quererte - Remasterizado           0
# 3  08FmqUhxtyLTn6pAh6bk45        El Prisionero - Remasterizado           0
# 4  08y9GfoqCWfOGsKdwojr5e                  Lady of the Evening           0
#
#    duration_ms  explicit              artists                  id_artists  \
# 0       126903         0              ['Uli']  ['45tIt06XoI0Iio4LBEVpls']
# 1        98200         0  ['Fernando Pessoa']  ['14jtPCOoNZwquk5wd9DxrY']
# 2       181640         0  ['Ignacio Corsini']  ['5LiOoJbxVSAMkBS2fUm3X2']
# 3       176907         0  ['Ignacio Corsini']  ['5LiOoJbxVSAMkBS2fUm3X2']
# 4       163080         0      ['Dick Haymes']  ['3BiJGZsyX9sJchTqcSA7Su']
#
# ...

# %%
df1.shape
# Out:
# (586672, 20)

# %%
merged_df.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20484\3139031502.py in <module>
# ----> 1 merged_df.shape
#
# NameError: name 'merged_df' is not defined

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 586672 entries, 0 to 586671
# Data columns (total 20 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   id                586672 non-null  object
#  1   name              586601 non-null  object
#  2   popularity        586672 non-null  int64
#  3   duration_ms       586672 non-null  int64
#  4   explicit          586672 non-null  int64
#  5   artists           586672 non-null  object
#  6   id_artists        586672 non-null  object
#  7   release_date      586672 non-null  datetime64[ns]
#  8   danceability      586672 non-null  float64
#  9   energy            586672 non-null  float64
#  10  key               586672 non-null  int64
#  11  loudness          586672 non-null  float64
#  12  mode              586672 non-null  int64
#  13  speechiness       586672 non-null  float64
#  14  acousticness      586672 non-null  float64
# ...

# %%
df1_copia = df1.copy()

# %%
 df1_copia = df1_copia.drop_duplicates(
  subset = ['name', 'artists', "id"],
  keep = 'last').reset_index(drop = True)
df1_copia
# Out:
#                             id                                 name  \
# 0       35iwgR4jXetI318WEWsa1Q                                Carve
# 1       021ht4sdgPcrDgSk7JTbKY  Capítulo 2.16 - Banquero Anarquista
# 2       07A5yehtSnoedViJAZkNnc   Vivo para Quererte - Remasterizado
# 3       08FmqUhxtyLTn6pAh6bk45        El Prisionero - Remasterizado
# 4       08y9GfoqCWfOGsKdwojr5e                  Lady of the Evening
# ...                        ...                                  ...
# 586667  5rgu12WBIHQtvej2MdHSH0                                  云与海
# 586668  0NuWgxEp51CutD2pJoF4OM                                blind
# 586669  27Y1N4Q4U3EfDU5Ubw8ws2            What They'll Say About Us
# 586670  45XJsGpFTyzbzeWK8VzR8S                      A Day At A Time
# 586671  5Ocn6dZ3BJFPWh4ylwFXtn                     Mar de Emociones
#
#         popularity  duration_ms  explicit                          artists  \
# ...

# %%
df2 = pd.read_csv(r"C:\Users\mareg\Downloads\archive (7)\artists.csv", encoding = "UTF-8")
df2.head()
# Out:
#                        id  followers genres  \
# 0  0DheY5irMjBUeLybbCUEZ2        0.0     []
# 1  0DlhY15l3wsrnlfGio2bjU        5.0     []
# 2  0DmRESX2JknGPQyO15yxg7        0.0     []
# 3  0DmhnbHjm1qw6NCYPeZNgJ        0.0     []
# 4  0Dn11fWM7vHQ3rinvWEl4E        2.0     []
#
#                                              name  popularity
# 0  Armid & Amir Zare Pashai feat. Sara Rouzbehani           0
# 1                                     ปูนา ภาวิณี           0
# 2                                           Sadaa           0
# 3                                       Tra'gruda           0
# 4                          Ioannis Panoutsopoulos           0

# %%
df2.columns
# Out:
# Index(['id', 'followers', 'genres', 'name', 'popularity'], dtype='object')

# %%
df2.shape
# Out:
# (1162095, 5)

# %%
df2_copia= df2.copy()

# %%
df2_copia = df2_copia.drop_duplicates(
  subset = ['name', 'popularity', "id"],
  keep = 'last').reset_index(drop = True)
df2_copia
# Out:
#                              id  followers            genres  \
# 0        0DheY5irMjBUeLybbCUEZ2        0.0                []
# 1        0DlhY15l3wsrnlfGio2bjU        5.0                []
# 2        0DmRESX2JknGPQyO15yxg7        0.0                []
# 3        0DmhnbHjm1qw6NCYPeZNgJ        0.0                []
# 4        0Dn11fWM7vHQ3rinvWEl4E        2.0                []
# ...                         ...        ...               ...
# 1162090  3cOzi726Iav1toV2LRVEjp     4831.0  ['black comedy']
# 1162091  6LogY6VMM3jgAE6fPzXeMl       46.0                []
# 1162092  19boQkDEIay9GaVAWkUhTa      257.0                []
# 1162093  5nvjpU3Y7L6Hpe54QuvDjy     2357.0  ['black comedy']
# 1162094  2bP2cNhNBdKXHC6AnqgyVp       40.0    ['new comedy']
#
#                                                    name  popularity
# 0        Armid & Amir Zare Pashai feat. Sara Rouzbehani           0
# 1                                           ปูนา ภาวิณี           0
# ...

# %%
art_track_merged = df1_copia.merge(df2_copia, how="left", on=["id","name", "popularity"])
art_track_merged.head()
# Out:
#                        id                                 name  popularity  \
# 0  35iwgR4jXetI318WEWsa1Q                                Carve           6
# 1  021ht4sdgPcrDgSk7JTbKY  Capítulo 2.16 - Banquero Anarquista           0
# 2  07A5yehtSnoedViJAZkNnc   Vivo para Quererte - Remasterizado           0
# 3  08FmqUhxtyLTn6pAh6bk45        El Prisionero - Remasterizado           0
# 4  08y9GfoqCWfOGsKdwojr5e                  Lady of the Evening           0
#
#    duration_ms  explicit              artists                  id_artists  \
# 0       126903         0              ['Uli']  ['45tIt06XoI0Iio4LBEVpls']
# 1        98200         0  ['Fernando Pessoa']  ['14jtPCOoNZwquk5wd9DxrY']
# 2       181640         0  ['Ignacio Corsini']  ['5LiOoJbxVSAMkBS2fUm3X2']
# 3       176907         0  ['Ignacio Corsini']  ['5LiOoJbxVSAMkBS2fUm3X2']
# 4       163080         0      ['Dick Haymes']  ['3BiJGZsyX9sJchTqcSA7Su']
#
# ...

# %% [markdown]
# No lo ejecuto

# %%
#Eliminamos la columna C del segundo DataFrame

df2 =df2.drop("name", axis=1)
df2 =df2.drop("artists", axis=1)
df2 =df2.drop("explicit", axis=1)
df2 =df2.drop("position", axis=1)
df2 =df2.drop("streams", axis=1)
df2 =df2.drop("date", axis=1)
print(df2)
# Realizamos el merge por la columna A
#merged_df = pd.merge(df1, df2, on='A', how='left', suffixes=('_x', '_y'))

# Imprimimos el resultado
#print(merged_df)
# Out:
#         country                track_id  \
# 0            de  20IvMlpi4U5RuDnAlXSRiV
# 1            jp  0V1K6MU0utODk4yNqZKsFv
# 2            tr  4qzZm5EIdFurBpDieEmVc9
# 3            tr  4qzZm5EIdFurBpDieEmVc9
# 4            tr  4qzZm5EIdFurBpDieEmVc9
# ...         ...                     ...
# 5428016      se  7731grGgxDd7aBNpGOjm9k
# 5428017      jp  4Vm9XIi9AD1oK39xACmqk5
# 5428018      jp  4Vm9XIi9AD1oK39xACmqk5
# 5428019      jp  4Vm9XIi9AD1oK39xACmqk5
# 5428020      dk  1selIVe40h0Ak2GVCzg5si
#
#                                              artist_genres
# 0                                       ['german hip hop']
# 1        ['japanese r&b', 'j-rock', 'japanese soul', 'j...
# 2            ['turkish singer-songwriter', 'turkish rock']
# 3            ['turkish singer-songwriter', 'turkish rock']
# 4            ['turkish singer-songwriter', 'turkish rock']
# ...                                                    ...
# 5428016                       ['swedish alternative rock']
# ...

# %%
df2_copia.isnull().sum()
# Out:
# id             0
# followers     11
# genres         0
# name           0
# popularity     0
# dtype: int64

# %%
df2_copia.shape
# Out:
# (1162095, 5)

# %%
art_track_merged.shape
# Out:
# (586672, 22)

# %%
art_track_merged.isnull().sum()
# Out:
# id                       0
# name                    71
# popularity               0
# duration_ms              0
# explicit                 0
# artists                  0
# id_artists               0
# release_date             0
# danceability             0
# energy                   0
# key                      0
# loudness                 0
# mode                     0
# speechiness              0
# acousticness             0
# instrumentalness         0
# liveness                 0
# valence                  0
# tempo                    0
# time_signature           0
# followers           586672
# genres              586672
# dtype: int64

# %%
df_nuevo["country"].unique()
# Out:
# array([nan, 'global', 'us', 'gb', 'se', 'ca', 'de', 'nl', 'dk', 'au',
#        'no', 'ie', 'be', 'ch', 'nz', 'pl', 'at', 'hu', 'cz', 'fi', 'gr',
#        'sk', 'ro', 'is', 'pt', 'sg', 'lv', 'lt', 'es', 'ee', 'ph', 'lu',
#        'hk', 'my', 'mt', 'it', 'cy', 'za', 'ae', 'jp', 'bg', 'tw', 'kr',
#        'fr', 'mx', 'ru', 'cl', 'ua', 'vn', 'th', 'gt', 'ec', 'pe', 'cr',
#        'pa', 'hn', 'bo', 'ni', 'do', 'sv', 'ad', 'eg', 'id', 'ar', 'br',
#        'tr', 'co', 'uy', 'py', 'sa', 'il', 'in', 'ma', 'by', 've', 'pk',
#        'kz', 'ng'], dtype=object)

# %%
# %matplotlib inline
msno.matrix(art_track_merged.sample(25000))
# Out:
# <AxesSubplot:>

# %%
df_charts_grouped = df_charts.groupby("artist")[["country"]].first().reset_index()

# %%
df_nuevo["country"] = df_nuevo["country"].fillna(method="ffill")

# %%
years = merged_df.release_date.dt.year
years
# Out:
# 0         1922
# 1         1922
# 2         1922
# 3         1922
# 4         1922
#           ...
# 586667    2020
# 586668    2020
# 586669    2020
# 586670    2021
# 586671    2015
# Name: release_date, Length: 586672, dtype: int64

# %%
merged_df['years'] = years
merged_df.head()
# Out:
#                        id                               name_x  popularity  \
# 0  35iwgR4jXetI318WEWsa1Q                                Carve           6
# 1  021ht4sdgPcrDgSk7JTbKY  Capítulo 2.16 - Banquero Anarquista           0
# 2  07A5yehtSnoedViJAZkNnc   Vivo para Quererte - Remasterizado           0
# 3  08FmqUhxtyLTn6pAh6bk45        El Prisionero - Remasterizado           0
# 4  08y9GfoqCWfOGsKdwojr5e                  Lady of the Evening           0
#
#    duration_ms  explicit_x            artists_x                  id_artists  \
# 0       126903           0              ['Uli']  ['45tIt06XoI0Iio4LBEVpls']
# 1        98200           0  ['Fernando Pessoa']  ['14jtPCOoNZwquk5wd9DxrY']
# 2       181640           0  ['Ignacio Corsini']  ['5LiOoJbxVSAMkBS2fUm3X2']
# 3       176907           0  ['Ignacio Corsini']  ['5LiOoJbxVSAMkBS2fUm3X2']
# 4       163080           0      ['Dick Haymes']  ['3BiJGZsyX9sJchTqcSA7Su']
#
# ...

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
num_tracks_by_year = merged_df.groupby(merged_df.release_date.dt.year)['release_date'].count()
print(num_tracks_by_year)
# Out:
# release_date
# 1900        1
# 1922      294
# 1923      657
# 1924      633
# 1925      903
# 1926     1421
# 1927     1200
# 1928     1376
# 1929     1126
# 1930     1606
# 1931     1016
# 1932     1095
# 1933     1126
# 1934      955
# 1935     1407
# 1936     1643
# 1937     1288
# 1938     1233
# 1939     1668
# 1940     1848
# 1941     1596
# 1942     1743
# 1943     1203
# 1944     1394
# 1945     1737
# 1946     2149
# 1947     1989
# 1948     2180
# 1949     2203
# 1950     3071
# 1951     2603
# 1952     2597
# 1953     2919
# 1954     3576
# 1955     4063
# 1956     3882
# 1957     3790
# 1958     4346
# 1959     4523
# 1960     5002
# 1961     4753
# 1962     5006
# 1963     4429
# 1964     4768
# 1965     5200
# 1966     2641
# 1967     4950
# 1968     5229
# 1969     5292
# 1970     5591
# 1971     5453
# 1972     5998
# 1973     5713
# 1974     6341
# 1975     6624
# 1976     6133
# 1977     6618
# 1978     6505
# 1979     6865
# 1980     8311
# 1981     7651
# ...

# %%
num_tracks_by_year.to_csv("num_tracks_by_year.csv")

# %%
years = num_tracks_by_year.index.tolist()
num_songs = num_tracks_by_year.values.tolist()

plt.bar(years, num_songs, width=0.8, color = "blue")
plt.title('Canciones lanzadas al mercado por año')
plt.xlabel('Year')
plt.ylabel('Number of tracks')
plt.xlim(1920, 2022)
plt.xticks(range(1920, 2022, 10), rotation=90)
plt.ylim([0, max(num_songs)+100])

plt.show()

# %%
merged_df.columns
# Out:
# Index(['id', 'name_x', 'popularity', 'duration_ms', 'explicit_x', 'artists_x',
#        'id_artists', 'release_date', 'danceability', 'energy', 'key',
#        'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness',
#        'liveness', 'valence', 'tempo', 'time_signature', 'date', 'country',
#        'position', 'streams', 'artists_y', 'artist_genres', 'duration',
#        'explicit_y', 'name_y', 'years'],
#       dtype='object')

# %%
grouped_data = merged_df.groupby('country')[['artists_x']]
grouped_data

# %%
num_genres = merged_df.groupby('country')[''].mean()
num_genres
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15292\2586915142.py in <module>
# ----> 1 num_genres = merged_df.groupby('country')[''].mean()
#       2 num_genres
#
# c:\Users\mareg\anaconda3\envs\general\lib\site-packages\pandas\core\groupby\generic.py in __getitem__(self, key)
#    1336                 stacklevel=find_stack_level(),
#    1337             )
# -> 1338         return super().__getitem__(key)
#    1339
#    1340     def _gotitem(self, key, ndim: int, subset=None):
#
# c:\Users\mareg\anaconda3\envs\general\lib\site-packages\pandas\core\base.py in __getitem__(self, key)
#     248         else:
#     249             if key not in self.obj:
# --> 250                 raise KeyError(f"Column not found: {key}")
#     251             subset = self.obj[key]
#     252             ndim = subset.ndim
#
# KeyError: 'Column not found: '

# %%
num_tracks_by_tempo = merged_df.groupby('years')[''].mean()
num_tracks_by_tempo
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15292\3406381270.py in <module>
# ----> 1 num_tracks_by_tempo = merged_df.groupby('years')[''].mean()
#       2 num_tracks_by_tempo
#
# c:\Users\mareg\anaconda3\envs\general\lib\site-packages\pandas\core\groupby\generic.py in __getitem__(self, key)
#    1336                 stacklevel=find_stack_level(),
#    1337             )
# -> 1338         return super().__getitem__(key)
#    1339
#    1340     def _gotitem(self, key, ndim: int, subset=None):
#
# c:\Users\mareg\anaconda3\envs\general\lib\site-packages\pandas\core\base.py in __getitem__(self, key)
#     248         else:
#     249             if key not in self.obj:
# --> 250                 raise KeyError(f"Column not found: {key}")
#     251             subset = self.obj[key]
#     252             ndim = subset.ndim
#
# ...

# %%
years = num_tracks_by_year.index.tolist()
country = num.values.tolist()

plt.bar(years, country, width=0.8, color = "blue")
plt.title('Canciones lanzadas al mercado por año')
plt.xlabel('Year')
plt.ylabel('Number of tracks')
plt.xlim(1920, 2022)
plt.xticks(range(1920, 2022, 10), rotation=90)
plt.ylim([0, max(country)+100])

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14976\467176012.py in <module>
#       1 years = num_tracks_by_year.index.tolist()
# ----> 2 country = num_tracks_by_country.values.tolist()
#       3
#       4 plt.bar(years, country, width=0.8, color = "blue")
#       5 plt.title('Canciones lanzadas al mercado por año')
#
# NameError: name 'num_tracks_by_country' is not defined

# %%
df_nuevosin.head()
# Out:
#                          id                                  name_x  \
# 0    4so0Wek9Ig1p6CRCHuINwW                         White Christmas
# 753  030mot3ZKR3oskfMsqDB2R  Have Yourself A Merry Little Christmas
# 796  04vLj9QUXoKdRlsp3gkURo       Mele Kalikimaka (Merry Christmas)
# 812  44mYhOVgerj2qPjkGDVA6n   It's Beginning To Look Like Christmas
# 863  7ehhnVu3JUWMaSJzY1zC4k                            Silver Bells
#
#      popularity  duration_ms  explicit_x  \
# 0            56       177480           0
# 753          50       162333           0
# 796          41       175333           0
# 812          37       166000           0
# 863          25       182667           0
#
#                                              artists_x  \
# 0    ['Bing Crosby', 'Ken Darby Singers', 'John Sco...
# 753                                   ['Judy Garland']
# 796             ['Bing Crosby', 'The Andrews Sisters']
# 812                                    ['Bing Crosby']
# ...

# %%
merged_df = pd.merge(df1, df2, on='ID')
print(merged_df)
